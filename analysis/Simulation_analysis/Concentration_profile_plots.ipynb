# %%
import numpy as np
from matplotlib import pyplot as plt
import numpy.linalg as nl
import os
import h5py
import fipy as fp
from fipy import Gmsh2D
import itertools
import cmath
import pandas as pd
import sys; sys.path.append('./')
import image_analysis as ia
from PIL import Image
from scipy.optimize import minimize

# %%
from matplotlib import rc
rc('font',**{'family':'serif','serif':['Times']})
rc('text', usetex=True)
plt.rcParams['xtick.labelsize']=20
plt.rcParams['ytick.labelsize']=20
plt.rcParams['font.size']=20
plt.rcParams["text.usetex"]=True

# %% [markdown]
# ## Concentration profiles for no RNA, presence of RNA, and active transcription of RNA

# %%
# Make the figures for concentration profile

# No RNA

figure_parameters = {'num_components': 2,
                     'component_indices': [0, 1],
                     'color_map': ["Greens", "PuRd"],
                     'titles': ["Protein", "RNA"],
                     'figure_size': [12, 6],
                     'keep_axes_labels': False,
                     'c0_range': [3.5, 4.6],
                     'c1_range': [0.1, 0.1]
                    }

path = "/nfs/arupclab001/npradeep96/Nucleolus_arrested_coarsening/Comparing_RNA_presence_and_transcription/Transcription_2/M_1_10.0_beta_-0.25_lamda_1.0_well_depth_0.0_gamma_0.1_kappa_0.01_K_0.0_c_initial_3.75_noise_variance_0.5_reaction_sigma_1.5_r_initial_0.0/"
fig, axs = ia.plot_concentration(path=path, figure_parameters=figure_parameters)
fig.savefig('Figures_for_paper/No_RNA_concentration.png', 
            dpi=600, format='png', bbox_inches='tight', pad_inches=0.0)
# fig.savefig('Figures_for_paper/No_RNA_concentration.pdf', 
#             dpi=600, format='pdf', bbox_inches='tight', pad_inches=0.0)
plt.show()
plt.close()

# Presence of RNA

figure_parameters = {'num_components': 2,
                     'component_indices': [0, 1],
                     'color_map': ["Greens", "PuRd"],
                     'titles': ["Protein", "RNA"],
                     'figure_size': [12, 6],
                     'keep_axes_labels': False,
                     'c0_range': [3.5, 4.6],
                     'c1_range': [14.9, 15.1]
                    }

path = "/nfs/arupclab001/npradeep96/Nucleolus_arrested_coarsening/Comparing_RNA_presence_and_transcription/Only_presence_2/M_1_10.0_beta_-0.25_lamda_1.0_well_depth_0.0_gamma_0.1_kappa_0.01_K_0.0_c_initial_3.75_noise_variance_0.5_reaction_sigma_1.5_r_initial_15.0"
fig, axs = ia.plot_concentration(path=path, figure_parameters=figure_parameters)
fig.savefig('Figures_for_paper/Presence_of_RNA_concentration.png', 
            dpi=600, format='png', bbox_inches='tight', pad_inches=0.0)
# fig.savefig('Figures_for_paper/Presence_of_RNA_concentration.pdf', 
#             dpi=600, format='pdf', bbox_inches='tight', pad_inches=0.0)
plt.show()
plt.close()


# Transcription of RNA

figure_parameters = {'num_components': 2,
                     'component_indices': [0, 1],
                     'color_map': ["Greens", "PuRd"],
                     'titles': ["Protein", "RNA"],
                     'figure_size': [12, 6],
                     'keep_axes_labels': False,
                     'c0_range': [3.5, 4.6],
                     'c1_range': [14.8, 15.5]
                    }

path = "/nfs/arupclab001/npradeep96/Nucleolus_arrested_coarsening/Comparing_RNA_presence_and_transcription/Transcription_2/M_1_10.0_beta_-0.25_lamda_1.0_well_depth_0.0_gamma_0.1_kappa_0.01_K_4.0_c_initial_3.75_noise_variance_0.5_reaction_sigma_1.5_r_initial_0.0"
fig, axs = ia.plot_concentration(path=path, figure_parameters=figure_parameters)
fig.savefig('Figures_for_paper/Active_RNA_Transcription_concentration.png', 
            dpi=600, format='png', bbox_inches='tight', pad_inches=0.0)
# fig.savefig('Figures_for_paper/Active_RNA_Transcription_concentration.tiff', 
#             dpi=600, format='tiff', bbox_inches='tight', pad_inches=0.0)
plt.show()
plt.close()

# %% [markdown]
# ## Concentration profiles for positive and negative delta_chi

# %%
# Make the figures for concentration profile

# Positive chi

figure_parameters = {'num_components': 2,
                     'component_indices': [0, 1],
                     'color_map': ["Greens", "PuRd"],
                     'titles': ["Protein", "RNA"],
                     'figure_size': [12, 6],
                     'keep_axes_labels': False,
                     'c0_range': [3.2, 4.9],
                     'c1_range': [14.8, 15.5]
                    }

path = path = "/nfs/arupclab001/npradeep96/Nucleolus_arrested_coarsening/Comparing_RNA_presence_and_transcription/Transcription_2/M_1_10.0_beta_-0.25_lamda_1.0_well_depth_0.0_gamma_0.1_kappa_0.01_K_4.0_c_initial_3.75_noise_variance_0.5_reaction_sigma_1.5_r_initial_0.0"
fig, axs = ia.plot_concentration(path=path, figure_parameters=figure_parameters)
fig.savefig('Figures_for_paper/Positive_chi.png', 
            dpi=600, format='png', bbox_inches='tight', pad_inches=0.0)
# fig.savefig('Figures_for_paper/No_RNA_concentration.pdf', 
#             dpi=600, format='pdf', bbox_inches='tight', pad_inches=0.0)
plt.show()
plt.close()

# Negative_chi

figure_parameters = {'num_components': 2,
                     'component_indices': [0, 1],
                     'color_map': ["Greens", "PuRd"],
                     'titles': ["Protein", "RNA"],
                     'figure_size': [12, 6],
                     'keep_axes_labels': False,
                     'c0_range': [3.2, 4.9],
                     'c1_range': [13.0, 19.0]
                    }

path = "/nfs/arupclab001/npradeep96/Nucleolus_arrested_coarsening/Negative_chi/M_1_10.0_beta_-0.25_lamda_1.0_well_depth_0.0_gamma_-0.1_kappa_0.01_K_4.0_c_initial_3.75_noise_variance_0.5_reaction_sigma_1.5_r_initial_0.0"
fig, axs = ia.plot_concentration(path=path, figure_parameters=figure_parameters, time_point=14)
fig.savefig('Figures_for_paper/Negative_chi.png', 
            dpi=600, format='png', bbox_inches='tight', pad_inches=0.0)
# fig.savefig('Figures_for_paper/Presence_of_RNA_concentration.pdf', 
#             dpi=600, format='pdf', bbox_inches='tight', pad_inches=0.0)
plt.show()
plt.close()

# %% [markdown]
# ## Time trajectories for coarsening and arrested coarsening

# %%
# Coarsening

figure_parameters = {'num_components': 1,
                     'component_indices': [0],
                     'color_map': ["Greens"],
                     'titles': ["Protein"],
                     'figure_size': [6, 6],
                     'keep_axes_labels': False,
                     'c0_range': [3.5, 4.6],
                    }

path = "/nfs/arupclab001/npradeep96/Nucleolus_arrested_coarsening/Comparing_RNA_presence_and_transcription/Transcription_2/M_1_10.0_beta_-0.25_lamda_1.0_well_depth_0.0_gamma_0.1_kappa_0.01_K_0.0_c_initial_3.75_noise_variance_0.5_reaction_sigma_1.5_r_initial_0.0/"

time_point_list = [1, 2, 3, 5, 10, 20, 30, 45, -1]

for t in time_point_list:
    fig, axs = ia.plot_concentration(path=path, figure_parameters=figure_parameters, time_point=t)
    fig.savefig('Figures_for_paper/Coarsening_t_{}.png'.format(t), 
                dpi=600, format='png', bbox_inches='tight', pad_inches=0.0)
    # fig.savefig('Figures_for_paper/No_RNA_concentration.pdf', 
    #             dpi=600, format='pdf', bbox_inches='tight', pad_inches=0.0)
    plt.show()
    plt.close()

# %%
# Arrested coarsening

figure_parameters = {'num_components': 1,
                     'component_indices': [0],
                     'color_map': ["Greens"],
                     'titles': ["Protein"],
                     'figure_size': [6, 6],
                     'keep_axes_labels': False,
                     'c0_range': [3.5, 4.6],
                    }

path = "/nfs/arupclab001/npradeep96/Nucleolus_arrested_coarsening/Comparing_RNA_presence_and_transcription/Transcription_2/M_1_10.0_beta_-0.25_lamda_1.0_well_depth_0.0_gamma_0.1_kappa_0.01_K_4.0_c_initial_3.75_noise_variance_0.5_reaction_sigma_1.5_r_initial_0.0/"

time_point_list = [1, 2, 3, 5, 10, 20, 30, 45, -1]

for t in time_point_list:
    fig, axs = ia.plot_concentration(path=path, figure_parameters=figure_parameters, time_point=t)
    fig.savefig('Figures_for_paper/Arrested_coarsening_t_{}.png'.format(t), 
                dpi=600, format='png', bbox_inches='tight', pad_inches=0.0)
    # fig.savefig('Figures_for_paper/No_RNA_concentration.pdf', 
    #             dpi=600, format='pdf', bbox_inches='tight', pad_inches=0.0)
    plt.show()
    plt.close()

# %% [markdown]
# ## Time trajectory for ON OFF ON simulations

# %%
# Arrested coarsening

figure_parameters = {'num_components': 1,
                     'component_indices': [0],
                     'color_map': ["Greens"],
                     'titles': ["Protein"],
                     'figure_size': [6, 6],
                     'keep_axes_labels': False,
                     'c0_range': [3.5, 4.6],
                    }

path = "/nfs/arupclab001/npradeep96/Nucleolus_arrested_coarsening/Transcription_ON_OFF_ON/M_1_10.0_beta_-0.25_lamda_1.0_well_depth_0.0_gamma_0.1_kappa_0.01_K_4.0_c_initial_3.75_noise_variance_0.5_reaction_sigma_1.5_r_initial_0.0/"

time_point_list = [80, 84, 87, 90, 95, 110, 150, 200, 250, 293, 294, 296, 298, 300, 302, 304, 306, 308, 310, 320, 330, 350, -1]

for t in time_point_list:
    fig, axs = ia.plot_concentration(path=path, figure_parameters=figure_parameters, time_point=t)
    fig.savefig('Figures_for_paper/ON_OFF_ON_t_{}.png'.format(t), 
                dpi=600, format='png', bbox_inches='tight', pad_inches=0.0)
    # fig.savefig('Figures_for_paper/No_RNA_concentration.pdf', 
    #             dpi=600, format='pdf', bbox_inches='tight', pad_inches=0.0)
    plt.show()
    plt.close()
